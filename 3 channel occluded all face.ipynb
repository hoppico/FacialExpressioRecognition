# %% [markdown]
# # **Facial Expressions Saturdays Ai**
#
# Proyecto de la primera edición de Donostia de Saturdays Ai 2020.

# %% [markdown]
# 1. Importación de librerías

# %%
import numpy as np 
import pandas as pd
import os
import cv2
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
from keras.utils import np_utils
from skimage import io


## Added libraries by Hooshiar
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
from skimage import img_as_ubyte
from skimage.util import img_as_float

# these lib are for applying mask
import dlib
import numpy as np
import imutils
#import cMake
# this lib are to compute Haar Wavelet of an image
import pywt


# settings: Load from the pre processed data:
# in case the images are preprocessed, they will be loaded from a specific folder, rather than being generated
loadPreprocessed = False;

featureMethod = 0   # 0 is for HoG, 1 is for Haar

loadDir = "data"

if loadPreprocessed:
    loadDir = "maskdata"

# %%
print(tf.version.VERSION)
# Out:
# 2.3.0

# %%
# this function is to apply mask on the input images
def maskify(img):
    ## set directories
    #os.chdir("C:\Users\ZolfaghH\Downloads\facial\Facial_Expression_Saturdays-master")
    #path ="predict/4disguested.jpg"

    #Initialize color [color_type] = (Blue, Green, Red)
    color_blue = (254,207,110)
    color_cyan = (255,200,0)
    color_black = (0, 0, 0)

    # Use input () function to capture from user requirements for mask type and mask colour
    choice1 = 1 #input("Please select the choice of mask color\nEnter 1 for blue\nEnter 2 for black:\n")
    #choice1 = int(choice1)

    if choice1 == 1:
        choice1 = color_blue
        #print('You selected mask color = blue')
    elif choice1 == 2:
        choice1 = color_black
        #print('You selected mask color = black')
    else:
        print("invalid selection, please select again.")
        #input("Please select the choice of mask color\nEnter 1 for blue\nEnter 2 for black :\n")


    choice2 = 3 #input("Please enter choice of mask type coverage \nEnter 1 for high \nEnter 2 for medium \nEnter 3 for low :\n")
    #choice2 = int(choice2)


    # print(choice2)



    # Loading the image and resizing, converting it to grayscale
    #img= cv2.imread(path)
    #img = imutils.resize(img, width = 500)
    
    if(len(img.shape)>2):
        gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    else:
        gray = img    

    # Initialize dlib's face detector
    detector = dlib.get_frontal_face_detector()

    """
    Detecting faces in the grayscale image and creating an object - faces to store the list of bounding rectangles coordinates
    The "1" in the second argument indicates that we should upsample the image 1 time.  
    This will make everything bigger and allow us to detect more faces
    """

    faces = detector(gray, 1)

    # printing the coordinates of the bounding rectangles
    #print(faces)
    #print("Number of faces detected: ", len(faces))

    """
    # Using a for loop in order to extract the specific coordinates (x1,x2,y1,y2)
    for face in faces:
      x1 = face.left()
      y1 = face.top()
      x2 = face.right()
      y2 = face.bottom()
      # Drawing a rectangle around the face detected
      cv2.rectangle(img, (x1,y1), (x2,y2),(0,255,0),3)
    cv2.imshow("image", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    """

    """
    Detecting facial landmarks using facial landmark predictor dlib.shape_predictor from dlib library
    This shape prediction method requires the file called "shape_predictor_68_face_landmarks.dat" to be downloaded
    Source of file: http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
    """
    # Path of file
    p = "shape_predictor_68_face_landmarks.dat"
    # Initialize dlib's shape predictor
    predictor = dlib.shape_predictor(p)

    # Get the shape using the predictor
    #img3=cv2.imread(path)
    for face in faces:
        #img3=cv2.imread(path)
        landmarks = predictor(gray, face)

        # for n in range(0,68):
        #     x = landmarks.part(n).x
        #     y = landmarks.part(n).y
        #     img_landmark = cv2.circle(img, (x, y), 4, (0, 0, 255), -1)


        points = []
        for i in range(1, 16):
            point = [landmarks.part(i).x, landmarks.part(i).y]
            points.append(point)
        # print(points)

        # Coordinates for the additional 3 points for wide, high coverage mask - in sequence
        mask_a = [((landmarks.part(42).x), (landmarks.part(15).y)),
                  ((landmarks.part(27).x), (landmarks.part(27).y)),
                  ((landmarks.part(39).x), (landmarks.part(1).y))]

        # Coordinates for the additional point for wide, medium coverage mask - in sequence
        mask_c = [((landmarks.part(29).x), (landmarks.part(29).y))]

        # Coordinates for the additional 5 points for wide, low coverage mask (lower nose points) - in sequence
        mask_e = [((landmarks.part(35).x), (landmarks.part(35).y)),
                  ((landmarks.part(34).x), (landmarks.part(34).y)),
                  ((landmarks.part(33).x), (landmarks.part(33).y)),
                  ((landmarks.part(32).x), (landmarks.part(32).y)),
                  ((landmarks.part(31).x), (landmarks.part(31).y))]

        fmask_a = points + mask_a
        fmask_c = points + mask_c
        fmask_e = points + mask_e

        # mask_type = {1: fmask_a, 2: fmask_c, 3: fmask_e}
        # mask_type[choice2]


        # Using Python OpenCV – cv2.polylines() method to draw mask outline for [mask_type]:
        # fmask_a = wide, high coverage mask,
        # fmask_c = wide, medium coverage mask,
        # fmask_e  = wide, low coverage mask

        fmask_a = np.array(fmask_a, dtype=np.int32)
        fmask_c = np.array(fmask_c, dtype=np.int32)
        fmask_e = np.array(fmask_e, dtype=np.int32)

        mask_type = {1: fmask_a, 2: fmask_c, 3: fmask_e}
        mask_type[choice2]


        # change parameter [mask_type] and color_type for various combination
        img2 = cv2.polylines(img, [mask_type[choice2]], True, choice1, thickness=2, lineType=cv2.LINE_8)

        # Using Python OpenCV – cv2.fillPoly() method to fill mask
        # change parameter [mask_type] and color_type for various combination
        img3 = cv2.fillPoly(img2, [mask_type[choice2]], choice1, lineType=cv2.LINE_AA)
        
        #convert to grayscale
        
    try:
        if(len(img3.shape)>2):
            img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
    except UnboundLocalError:
        img3=cv2.imread(path)
        return img3, False;
        
            

    # cv2.imshow("image with mask outline", img2)
    #plt.imshow(img3)

    
    return img3, True;

# %%
def computeHaar(img):
    h, w = img.shape
    
    img = cv2.resize(img, (w*2,h*2))
    # Convert to float for more resolution for use with pywt
    img = np.float32(img)
    img /= 255

    # Wavelet transform of image,
    coeffs2 = pywt.dwt2(img, 'haar')
    LL, (LH, HL, HH) = coeffs2
    img = LH + HL + HH   # summation of horizental an vertical and diagonal

    #fig = plt.figure(figsize=(12, 3))
    #for i, a in enumerate([LL, LH, HL, HH]):
    #    ax = fig.add_subplot(1, 4, i + 1)
    #    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    #    ax.set_title(titles[i], fontsize=10)
    #    ax.set_xticks([])
    #    ax.set_yticks([])

    #fig.tight_layout()
    #plt.show()

    img = cv2.normalize(img, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
    img = np.uint8(img)

    #plt.imshow(img)
    #cv2.imwrite("HaarWavelet.jpg", img)

    #print(img[0,0])
    
    return img

def computeHoG(img):
    fd, hog_image = hog(img, orientations=9, pixels_per_cell=(2, 2),cells_per_block=(1, 1), visualize=True, multichannel=False)
    hog_image = cv2.normalize(hog_image, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
    hog_image = np.uint8(hog_image)
    return hog_image

# %%
#  optional section: To validate the function of faceFeatures
path = "predict/3surprised.jpg"
img = imread(path)

if(len(img.shape)>2):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#img, stat = maskify(img)

feat_img = computeHaar(img)

img, stat = faceFeatures(img, feat_img)
print(stat)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-621706b23b71> in <module>
#       9 feat_img = computeHaar(img)
#      10
# ---> 11 img, stat = faceFeatures(img, feat_img)
#      12 print(stat)
#      13 plt.imshow(img)
#
# NameError: name 'faceFeatures' is not defined

# %% [markdown]
# 2. Importación data training

# %%
#feature extraction on training data

loc1 = loadDir + '/train/0'
loc2 = loadDir + '/train/1'
loc3 = loadDir + '/train/2'
loc4 = loadDir + '/train/3'
loc5 = loadDir + '/train/4'
loc6 = loadDir + '/train/5'
loc7 = loadDir + '/train/6'

features = []

if loadPreprocessed:

    for i in tqdm(os.listdir(loc1)):
        features.append(imread(os.path.join(loc1,i),0))

    for i in tqdm(os.listdir(loc2)):
        features.append(imread(os.path.join(loc2,i),0))

    for i in tqdm(os.listdir(loc3)):
        features.append(imread(os.path.join(loc3,i),0))

    for i in tqdm(os.listdir(loc4)):
        features.append(imread(os.path.join(loc4,i),0))

    for i in tqdm(os.listdir(loc5)):
        features.append(imread(os.path.join(loc5,i),0))

    for i in tqdm(os.listdir(loc6)):
        features.append(imread(os.path.join(loc6,i),0))

    for i in tqdm(os.listdir(loc7)):
        features.append(imread(os.path.join(loc7,i),0))

else:
    
##### modified code by Hooshiar to read image and compute HoG    
    for i in tqdm(os.listdir(loc1)):
        path = os.path.join(loc1,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc2)):
        path = os.path.join(loc2,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc3)):
        path = os.path.join(loc3,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc4)):
        path = os.path.join(loc4,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc5)):
        path = os.path.join(loc5,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc6)):
        path = os.path.join(loc6,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)

    for i in tqdm(os.listdir(loc7)):
        path = os.path.join(loc7,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            features.append(img_comb)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 3995/3995 [2:24:24<00:00,  2.17s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 436/436 [10:14<00:00,  1.41s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 4097/4097 [1:29:30<00:00,  1.31s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 7215/7215 [2:39:02<00:00,  1.32s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 4830/4830 [1:45:59<00:00,  1.32s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 3171/3171 [1:11:48<00:00,  1.36s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 4965/4965 [1:51:22<00:00,  1.35s/it]

# %%
labels = []

for i in os.listdir('maskdata/train/0'):
    labels.append(0)
for i in os.listdir('maskdata/train/1'):
    labels.append(1)
for i in os.listdir('maskdata/train/2'):
    labels.append(2)
for i in os.listdir('maskdata/train/3'):
    labels.append(3)
for i in os.listdir('maskdata/train/4'):
    labels.append(4)
for i in os.listdir('maskdata/train/5'):
    labels.append(5)
for i in os.listdir('maskdata/train/6'):
    labels.append(6)

# %%
print(features[0][20,20])
plt.imshow(features[0])
# Out:
# [141   0  75]

# %%
#feature extraction on testing data

loc1 = loadDir + '/test/0'
loc2 = loadDir + '/test/1'
loc3 = loadDir + '/test/2'
loc4 = loadDir + '/test/3'
loc5 = loadDir + '/test/4'
loc6 = loadDir + '/test/5'
loc7 = loadDir + '/test/6'


test_features = []

if loadPreprocessed:

    for i in tqdm(os.listdir(loc1)):
        test_features.append(cv2.imread(os.path.join(loc1,i),0))

    for i in tqdm(os.listdir(loc2)):
        test_features.append(cv2.imread(os.path.join(loc2,i),0))

    for i in tqdm(os.listdir(loc3)):
        test_features.append(cv2.imread(os.path.join(loc3,i),0))

    for i in tqdm(os.listdir(loc4)):
        test_features.append(cv2.imread(os.path.join(loc4,i),0))

    for i in tqdm(os.listdir(loc5)):
        test_features.append(cv2.imread(os.path.join(loc5,i),0))

    for i in tqdm(os.listdir(loc6)):
        test_features.append(cv2.imread(os.path.join(loc6,i),0))

    for i in tqdm(os.listdir(loc7)):
        test_features.append(cv2.imread(os.path.join(loc7,i),0))

else:
    
    # Modified by Hooshiar to generate HoGof image and just use it for testing

    for i in tqdm(os.listdir(loc1)):
        path = os.path.join(loc1,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc2)):
        path = os.path.join(loc2,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc3)):
        path = os.path.join(loc3,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc4)):
        path = os.path.join(loc4,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc5)):
        path = os.path.join(loc5,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc6)):
        path = os.path.join(loc6,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)

    for i in tqdm(os.listdir(loc7)):
        path = os.path.join(loc7,i)
        img = imread(path)
        # maskify
        img, stat = maskify(img)
        
        if stat==True:
            if(len(img.shape)>2):
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            hog_img = computeHoG(img)
            haar_img = computeHaar(img)

            img_comb = np.zeros((48,48,3), np.uint8)
            img_comb[:,:,0] = img
            img_comb[:,:,1] = hog_img
            img_comb[:,:,2] = haar_img

            cv2.imwrite("mask"+path, img_comb)
            test_features.append(img_comb)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 491/491 [11:11<00:00,  1.37s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 55/55 [01:17<00:00,  1.41s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 529/529 [12:03<00:00,  1.37s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 879/879 [19:47<00:00,  1.35s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 594/594 [12:15<00:00,  1.24s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 416/416 [08:42<00:00,  1.26s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 626/626 [13:11<00:00,  1.26s/it]

# %%
labels_test = []
for i in os.listdir('maskdata/test/0'):
    labels_test.append(0)
for i in os.listdir('maskdata/test/1'):
    labels_test.append(1)
for i in os.listdir('maskdata/test/2'):
    labels_test.append(2)
for i in os.listdir('maskdata/test/3'):
    labels_test.append(3)
for i in os.listdir('maskdata/test/4'):
    labels_test.append(4)
for i in os.listdir('maskdata/test/5'):
    labels_test.append(5)
for i in os.listdir('maskdata/test/6'):
    labels_test.append(6)

# %%
train_data = pd.DataFrame()
test_data = pd.DataFrame()

# %%
len(features)
# Out:
# 19960

# %%
train_data['emotion'] = labels
train_data['pixel_values'] = features
test_data['emotion'] = labels_test
test_data['pixel_values'] = test_features

# %%
test_data.head()
# Out:
#    emotion                                       pixel_values
# 0        0  [[[179, 0, 90], [175, 0, 91], [176, 0, 92], [1...
# 1        0  [[[103, 0, 124], [126, 0, 139], [109, 0, 153],...
# 2        0  [[[27, 0, 135], [29, 0, 111], [88, 0, 116], [3...
# 3        0  [[[11, 0, 117], [11, 0, 117], [11, 0, 117], [1...
# 4        0  [[[80, 0, 112], [82, 0, 96], [107, 0, 89], [14...

# %%
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

def setup_axe(axe,df,title):
    df['emotion'].value_counts(sort=False).plot(ax=axe, kind='bar', rot=0)
    axe.set_xticklabels(emotion_labels)
    axe.set_xlabel("Emotions")
    axe.set_ylabel("Count")
    axe.set_title(title)
    
    # set individual bar lables using above list
    for i in axe.patches:
         axe.text(i.get_x()-.05, i.get_height()+120, \
                str(round((i.get_height()), 2)), fontsize=14, color='red',
                    rotation=0)

import matplotlib.pyplot as plt   
fig, axes = plt.subplots(1,2, figsize=(20,8), sharey=True)
setup_axe(axes[0],train_data,'train')
setup_axe(axes[1],test_data,'test')
plt.show()

# %%
print(np.array(features))
# Out:
# [[[[ 94   0  70]
#    [ 96   0  80]
#    [105   0  82]
#    ...
#    [100   0  52]
#    [ 96   0  43]
#    [ 92   0  41]]
#
#   [[103   0  65]
#    [109  19  61]
#    [106   0  58]
#    ...
#    [ 98  12  56]
#    [ 95   0  52]
#    [ 94   9  44]]
#
#   [[107   0  50]
#    [101   0  43]
#    [ 88   0  54]
#    ...
#    [ 95   0  49]
#    [ 98   0  56]
#    [ 97   0  47]]
#
#   ...
#
#   [[103   0  91]
#    [ 96  41  65]
#    [ 77   0  42]
#    ...
#    [ 94  49  72]
#    [100   0  56]
#    [102  33  43]]
#
#   [[101   0  77]
#    [ 94   0  82]
#    [ 86   0  79]
#    ...
#    [ 96   0 105]
#    [ 95   0  70]
#    [ 88   0  46]]
#
#   [[ 96   0  77]
#    [ 94   7  72]
#    [ 90   0  84]
#    ...
#    [ 91  23 106]
#    [ 94   0 109]
#    [ 91  38  82]]]
#
#
#  [[[124   0 151]
#    [126   0 150]
#    [122   0 147]
#    ...
#    [115   0 129]
#    [127   0 140]
#    [127   0 120]]
#
#   [[125   0 151]
#    [125   1 149]
#    [120   0 149]
#    ...
#    [120  25 122]
#    [124   0 141]
#    [118  12 137]]
#
#   [[124   0 151]
#    [123   0 151]
#    [124   0 156]
#    ...
#    [129   0 109]
#    [122   0 123]
#    [119   0 146]]
#
#   ...
#
#   [[132   0 188]
#    [133  69 188]
#    [115   0 121]
#    ...
#    [132  13 185]
#    [124   0 185]
#    [121   2 186]]
#
#   [[125   0 188]
#    [126   0 187]
#    [130   0 196]
#    ...
#    [132   0 186]
#    [125   0 182]
#    [124   0 187]]
#
#   [[128   0 186]
#    [126   2 184]
#    [126   0 185]
#    ...
#    [122  51 193]
#    [128   0 183]
#    [123   2 184]]]
#
#
#  [[[140   0  30]
#    [140   0  24]
#    [138   0  21]
#    ...
#    [137   0  37]
#    [139   0  44]
#    [139   0  37]]
#
#   [[142   0  31]
#    [140   6  22]
#    [137   0  21]
#    ...
#    [145  46  37]
#    [138   0  35]
#    [134   3  41]]
#
#   [[143   0  27]
#    [140   0  22]
#    [137   0  19]
#    ...
#    [147   0  33]
#    [133   0  34]
#    [138   0  40]]
#
#   ...
#
#   [[137   0  29]
#    [138   3  29]
#    [134   0  26]
#    ...
#    [105 106 118]
#    [112   0 132]
#    [124  39 148]]
#
#   [[136   0  30]
#    [138   0  30]
#    [136   0  27]
#    ...
#    [114   0 154]
#    [111   0 159]
#    [121   0 166]]
#
#   [[138   0  32]
#    [138   2  29]
#    [138   0  28]
#    ...
#    [130  32 172]
#    [129   0 173]
#    [133  18 173]]]
#
#
#  ...
#
#
#  [[[138   0 107]
#    [137   0 109]
#    [132   0 105]
#    ...
#    [ 99   0 183]
#    [137   0 185]
#    [139   0 186]]
#
#   [[140   0 107]
#    [137   4 113]
#    [131   0 115]
#    ...
#    [ 94 142 179]
#    [137   0 187]
#    [139   3 185]]
#
#   [[137   0  99]
#    [137   0 111]
#    [137   0 114]
#    ...
#    [ 89   0 173]
#    [136   0 188]
#    [142   0 184]]
#
#   ...
#
#   [[141   0  62]
#    [142   3  61]
#    [141   0  62]
#    ...
#    [148  20  60]
#    [143   0  60]
#    [140   5  57]]
#
#   [[141   0  59]
#    [141   0  59]
#    [139   0  58]
#    ...
#    [140   0  55]
#    [140   0  61]
#    [137   0  60]]
#
#   [[141   0  57]
#    [140   2  59]
#    [139   0  61]
#    ...
#    [138  19  57]
#    [137   0  60]
#    [139   2  59]]]
#
#
#  [[[117   0 137]
#    [117   0 137]
#    [115   0 138]
#    ...
#    [116   0 143]
#    [117   0 142]
#    [116   0 140]]
#
#   [[117   0 138]
#    [117   0 137]
#    [115   0 138]
#    ...
#    [117   2 145]
#    [117   0 143]
#    [115   3 141]]
#
#   [[117   0 137]
#    [115   0 136]
#    [114   0 139]
#    ...
#    [117   0 148]
#    [118   0 144]
#    [114   0 146]]
#
#   ...
#
#   [[117   0 163]
#    [117   2 165]
#    [117   0 166]
#    ...
#    [ 94 113 176]
#    [119   0 169]
#    [116   5 170]]
#
#   [[116   0 165]
#    [114   0 164]
#    [114   0 166]
#    ...
#    [ 89   0 173]
#    [118   0 169]
#    [118   0 170]]
#
#   [[115   0 168]
#    [115   2 169]
#    [117   0 168]
#    ...
#    [ 86 118 171]
#    [120   0 169]
#    [117   3 166]]]
#
#
#  [[[135   0 113]
#    [134   0  75]
#    [105   0  74]
#    ...
#    [125   0 103]
#    [109   0  97]
#    [110   0 127]]
#
#   [[141   0 104]
#    [128  29  65]
#    [ 92   0  79]
#    ...
#    [128 108 110]
#    [110   0  86]
#    [117  24 105]]
#
#   [[132   0  86]
#    [110   0  75]
#    [ 81   0  98]
#    ...
#    [125   0 130]
#    [115   0 116]
#    [119   0  93]]
#
#   ...
#
#   [[115   0 255]
#    [115   0 254]
#    [118   0 255]
#    ...
#    [114   6 206]
#    [111   0 210]
#    [111  12 214]]
#
#   [[118   0 255]
#    [128   0 255]
#    [148   0 251]
#    ...
#    [113   0 206]
#    [112   0 208]
#    [115   0 212]]
#
#   [[125   0 251]
#    [145  26 229]
#    [152   0 197]
#    ...
#    [114   4 210]
#    [113   0 211]
#    [114   3 213]]]]

# %%
features = np.array(features).reshape(-1,48,48,3)
test_features = np.array(test_features).reshape(-1,48,48,3)

features = features/255
test_features = test_features/255

labels = np_utils.to_categorical(labels)
labels_test =np_utils.to_categorical(labels_test)

# %%
print('Training features shape ',features.shape)
print('Training labels shape',labels.shape)
print('Testing features shape ',test_features.shape)
print('Testing labels shape',labels_test.shape)
# Out:
# Training features shape  (19960, 48, 48, 3)
# Training labels shape (19960, 7)
# Testing features shape  (2743, 48, 48, 3)
# Testing labels shape (2743, 7)

# %%
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from sklearn.metrics import accuracy_score
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras.utils import np_utils
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten, Conv2D, BatchNormalization,MaxPooling2D
from tensorflow.keras.optimizers import Adam, RMSprop

# %%
def create_model():
    model = Sequential()
    input_shape = (48,48,3)
    model.add(Conv2D(64, (5, 5), input_shape=input_shape,activation='relu', padding='same'))
    model.add(Conv2D(64, (5, 5), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (5, 5),activation='relu',padding='same'))
    model.add(Conv2D(128, (5, 5),activation='relu',padding='same'))
    model.add(Conv2D(128, (5, 5),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (3, 3),activation='relu',padding='same'))
    model.add(Conv2D(256, (3, 3),activation='relu',padding='same'))
    model.add(Conv2D(256, (3, 3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(128))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    
    
    model.add(Flatten())
    model.add(Dense(64))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    
    
    model.add(Dense(7))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 48, 48, 64)        4864
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 48, 48, 64)        102464
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 24, 24, 128)       204928
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 24, 24, 128)       409728
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 24, 24, 128)       409728
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 12, 12, 256)       590080
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 12, 12, 256)       1024
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 455
# _________________________________________________________________
# activation_11 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 3,798,087
# Trainable params: 3,796,807
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
checkpoint_path = "training_3/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 best_only_model=True,
                                                 verbose=1)

# %%
model.save_weights(checkpoint_path.format(epoch=0))

# %%
history = model.fit(x=features, 
            y=labels,
            epochs=10, 
            steps_per_epoch = len(features)/64,
            verbose=1, 
            callbacks = [cp_callback],
            validation_data=(test_features,labels_test),  
            validation_steps = len(test_features)/64)
# Out:
# Epoch 1/10
# 312/311 [==============================] - ETA: 0s - loss: 1.3823 - accuracy: 0.4906
# Epoch 00001: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 778s 2s/step - loss: 1.3823 - accuracy: 0.4906 - val_loss: 1.3195 - val_accuracy: 0.4954
# Epoch 2/10
# 312/311 [==============================] - ETA: 0s - loss: 1.1525 - accuracy: 0.5779
# Epoch 00002: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 823s 3s/step - loss: 1.1525 - accuracy: 0.5779 - val_loss: 1.2295 - val_accuracy: 0.5355
# Epoch 3/10
# 312/311 [==============================] - ETA: 0s - loss: 1.0271 - accuracy: 0.6242
# Epoch 00003: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 861s 3s/step - loss: 1.0271 - accuracy: 0.6242 - val_loss: 1.1153 - val_accuracy: 0.5953
# Epoch 4/10
# 312/311 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.6782
# Epoch 00004: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 819s 3s/step - loss: 0.8918 - accuracy: 0.6782 - val_loss: 1.1404 - val_accuracy: 0.5891
# Epoch 5/10
# 312/311 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.7259
# Epoch 00005: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 834s 3s/step - loss: 0.7651 - accuracy: 0.7259 - val_loss: 1.0026 - val_accuracy: 0.6584
# Epoch 6/10
# 312/311 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.7733
# Epoch 00006: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 842s 3s/step - loss: 0.6297 - accuracy: 0.7733 - val_loss: 1.0475 - val_accuracy: 0.6591
# Epoch 7/10
# 312/311 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8244
# Epoch 00007: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 918s 3s/step - loss: 0.5049 - accuracy: 0.8244 - val_loss: 1.0757 - val_accuracy: 0.6719
# Epoch 8/10
# 312/311 [==============================] - ETA: 0s - loss: 0.3849 - accuracy: 0.8674
# Epoch 00008: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 784s 3s/step - loss: 0.3849 - accuracy: 0.8674 - val_loss: 1.0623 - val_accuracy: 0.7156
# Epoch 9/10
# 312/311 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.8931
# Epoch 00009: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 761s 2s/step - loss: 0.3109 - accuracy: 0.8931 - val_loss: 1.0868 - val_accuracy: 0.7175
# Epoch 10/10
# 312/311 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9142
# Epoch 00010: saving model to training_3\cp.ckpt
# 312/311 [==============================] - 751s 2s/step - loss: 0.2484 - accuracy: 0.9142 - val_loss: 1.3905 - val_accuracy: 0.6526

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
model.load_weights(latest)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 best_only_model=True,
                                                 verbose=1)

# %%
model.fit(x=features, 
            y=labels,
            epochs=10, 
            steps_per_epoch = len(features)/64,
            verbose=1, 
            callbacks = [cp_callback],
            validation_data=(test_features,labels_test),  
            validation_steps = len(test_features)/64)
# Out:
# Epoch 1/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9880
# Epoch 00001: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 810s 3s/step - loss: 0.0395 - accuracy: 0.9880 - val_loss: 3.0935 - val_accuracy: 0.5414
# Epoch 2/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9778
# Epoch 00002: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 797s 3s/step - loss: 0.0658 - accuracy: 0.9778 - val_loss: 2.8444 - val_accuracy: 0.5187
# Epoch 3/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9748
# Epoch 00003: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 735s 2s/step - loss: 0.0739 - accuracy: 0.9748 - val_loss: 2.9866 - val_accuracy: 0.5349
# Epoch 4/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9801
# Epoch 00004: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 732s 2s/step - loss: 0.0551 - accuracy: 0.9801 - val_loss: 3.0689 - val_accuracy: 0.5462
# Epoch 5/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9871
# Epoch 00005: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 755s 2s/step - loss: 0.0408 - accuracy: 0.9871 - val_loss: 2.9160 - val_accuracy: 0.5511
# Epoch 6/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9834
# Epoch 00006: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 736s 2s/step - loss: 0.0497 - accuracy: 0.9834 - val_loss: 3.2178 - val_accuracy: 0.5243
# Epoch 7/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9855
# Epoch 00007: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 719s 2s/step - loss: 0.0445 - accuracy: 0.9855 - val_loss: 3.0966 - val_accuracy: 0.5377
# Epoch 8/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9862
# Epoch 00008: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 737s 2s/step - loss: 0.0417 - accuracy: 0.9862 - val_loss: 2.8928 - val_accuracy: 0.5474
# Epoch 9/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9850
# Epoch 00009: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 710s 2s/step - loss: 0.0463 - accuracy: 0.9850 - val_loss: 3.0352 - val_accuracy: 0.5345
# Epoch 10/10
# 312/311 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9840
# Epoch 00010: saving model to training_2\cp.ckpt
# 312/311 [==============================] - 694s 2s/step - loss: 0.0465 - accuracy: 0.9840 - val_loss: 3.3102 - val_accuracy: 0.5543

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
model.load_weights(latest)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 best_only_model=True,
                                                 verbose=1)

# %%
history =model.fit(x=features, 
            y=labels,
            epochs=1, 
            steps_per_epoch = len(features)/64,
            verbose=1, 
            callbacks = [cp_callback],
            validation_data=(test_features,labels_test),  
            validation_steps = len(test_features)/64)
# Out:
# 449/448 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9743
# Epoch 00001: saving model to training_2\cp.ckpt
# 449/448 [==============================] - 773s 2s/step - loss: 0.0771 - accuracy: 0.9743 - val_loss: 2.7980 - val_accuracy: 0.5252

# %%
# !mkdir -p saved_model
model.save('saved_model/3Channelmodel_occluded_allface')
# Out:
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file saved_model already exists.
# Error occurred while processing: saved_model.

# %%
from sklearn.externals import joblib 
joblib.dump(model, 'modelo_entrenado.pkl')
# Out:
# C:\Users\ZolfaghH\AppData\Roaming\Python\Python37\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-b81c896ad0ea> in <module>
#       1 from sklearn.externals import joblib
# ----> 2 joblib.dump(model, 'modelo_entrenado.pkl')
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# D:\Anaconda\lib\pickle.py in dump(self, obj)
#     435         if self.proto >= 4:
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#     439         self.framer.end_framing()
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_list(self, obj)
#     817
#     818         self.memoize(obj)
# --> 819         self._batch_appends(obj)
#     820
#     821     dispatch[list] = save_list
#
# D:\Anaconda\lib\pickle.py in _batch_appends(self, items)
#     841                 write(MARK)
#     842                 for x in tmp:
# --> 843                     save(x)
#     844                 write(APPENDS)
#     845             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_list(self, obj)
#     817
#     818         self.memoize(obj)
# --> 819         self._batch_appends(obj)
#     820
#     821     dispatch[list] = save_list
#
# D:\Anaconda\lib\pickle.py in _batch_appends(self, items)
#     844                 write(APPENDS)
#     845             elif n:
# --> 846                 save(tmp[0])
#     847                 write(APPEND)
#     848             # else tmp is empty, and we're done
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# D:\Anaconda\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# D:\Anaconda\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# D:\Anaconda\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# D:\Anaconda\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# D:\Anaconda\lib\pickle.py in save(self, obj, save_persistent_id)
#     522             reduce = getattr(obj, "__reduce_ex__", None)
#     523             if reduce is not None:
# --> 524                 rv = reduce(self.proto)
#     525             else:
#     526                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle _thread.RLock objects

# %%
new_model = tf.keras.models.load_model('saved_model/3Channelmodel_occluded_allface')

# %%
loss, acc = new_model.evaluate(test_features, labels_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 86/86 - 20s - loss: 1.3905 - accuracy: 0.6526
# Restored model, accuracy: 65.26%

# %%
test_true = np.argmax(labels_test, axis=1)
test_pred = np.argmax(model.predict(test_features), axis=1)
print("CNN Model Accuracy on testing data: {:.4f}".format(accuracy_score(test_true, test_pred)))
# Out:
# CNN Model Accuracy on testing data: 0.6526

# %%
predicted_classes = cnn_model.predict_classes(test_features)

# %%
from sklearn.metrics import classification_report

print(classification_report(test_true, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.81      0.57       377
#            1       0.80      0.80      0.80        51
#            2       0.73      0.60      0.66       364
#            3       0.87      0.59      0.70       743
#            4       0.52      0.69      0.59       353
#            5       0.78      0.83      0.80       329
#            6       0.72      0.53      0.61       526
#
#     accuracy                           0.65      2743
#    macro avg       0.69      0.69      0.68      2743
# weighted avg       0.71      0.65      0.66      2743

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
